# %%
import pandas as pd
import numpy as numpy

# %%
df = pd.read_csv('synthetic_space_objects.csv')

# %%
df = df[['classe','velocidade_relativa_km_s',
       'excentricidade_orbital', 'emissao_sinal_rf', 'taxa_rotacao_rpm',
       'assinatura_termica_k', 'inclinacao_orbital_graus',
       'variacao_brilho_porcentagem','rcs_m2', 'albedo']]

df.head(20)
# Out:
#            classe  velocidade_relativa_km_s  excentricidade_orbital  \
# 0   Lixo Espacial                  6.164656                0.073249
# 1       Asteroide                  3.390391                0.891368
# 2   Lixo Espacial                  7.460445                0.086218
# 3   Lixo Espacial                  7.065504                0.007788
# 4        Satelite                  8.223489                0.016006
# 5        Satelite                  7.856700                0.039959
# 6        Satelite                  7.277249                0.021126
# 7       Asteroide                  0.663217                0.675753
# 8   Lixo Espacial                  6.674415                0.094479
# 9   Lixo Espacial                  9.121109                0.023144
# 10       Satelite                  7.415943                0.044201
# 11      Asteroide                 26.329318                0.575882
# 12      Asteroide                 22.858654                0.658669
# ...
