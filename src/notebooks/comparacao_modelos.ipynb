# %%
# Instalação
# !pip install pycaret

import pandas as pd
from pycaret.classification import *

# 1) Carregar dados
df = pd.read_csv('./synthetic_space_objects_v2.csv')

# 2) Iniciar experimento AutoML
exp = setup(
    data=df,
    target='classe',
    session_id=42,
    train_size=0.7,
    normalize=True,
    fold=5,
    verbose=True,
    use_gpu=False
)

# 3) Comparar modelos
best_model = compare_models()

# 4) Ver leaderboard completo
leaderboard = pull()
print(leaderboard.head(10))

# 5) Ajustar o melhor modelo
tuned_model = tune_model(best_model)

# 6) Avaliar visualmente
plot_model(tuned_model, plot='residuals')
plot_model(tuned_model, plot='error')
plot_model(tuned_model, plot='feature')

# 7) Finalizar modelo
final_model = finalize_model(tuned_model)

# 8) Previsões
predictions = predict_model(final_model)
print(predictions.head())

# 9) Salvar modelo
save_model(final_model, './pycaret_space_objects_model')
# Out:
# <style type="text/css">
# #T_aacf7_row9_col1, #T_aacf7_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_aacf7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aacf7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_aacf7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aacf7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aacf7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_aacf7_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aacf7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_aacf7_row1_col1" class="data row1 col1" >classe</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aacf7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_aacf7_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aacf7_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_aacf7_row3_col1" class="data row3 col1" >Asteroide: 0, Lixo Espacial: 1, Satelite: 2</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aacf7_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_aacf7_row4_col1" class="data row4 col1" >(1500, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aacf7_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_aacf7_row5_col1" class="data row5 col1" >(1500, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aacf7_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_aacf7_row6_col1" class="data row6 col1" >(1050, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aacf7_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_aacf7_row7_col1" class="data row7 col1" >(450, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aacf7_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_aacf7_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aacf7_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_aacf7_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_aacf7_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_aacf7_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_aacf7_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_aacf7_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aacf7_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_aacf7_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_aacf7_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_aacf7_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_aacf7_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_aacf7_row14_col1" class="data row14 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_aacf7_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_aacf7_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_aacf7_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_aacf7_row16_col1" class="data row16 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_aacf7_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_aacf7_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_aacf7_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_aacf7_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_aacf7_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_aacf7_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_aacf7_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_aacf7_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_aacf7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_aacf7_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_aacf7_row21_col1" class="data row21 col1" >dd8a</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_db0f3 th {
#   text-align: left;
# }
# #T_db0f3_row0_col0, #T_db0f3_row0_col2, #T_db0f3_row1_col0, #T_db0f3_row1_col1, #T_db0f3_row1_col2, #T_db0f3_row1_col3, #T_db0f3_row1_col4, #T_db0f3_row1_col5, #T_db0f3_row1_col6, #T_db0f3_row1_col7, #T_db0f3_row2_col0, #T_db0f3_row2_col1, #T_db0f3_row2_col3, #T_db0f3_row2_col4, #T_db0f3_row2_col5, #T_db0f3_row2_col6, #T_db0f3_row2_col7, #T_db0f3_row3_col0, #T_db0f3_row3_col1, #T_db0f3_row3_col2, #T_db0f3_row3_col3, #T_db0f3_row3_col4, #T_db0f3_row3_col5, #T_db0f3_row3_col6, #T_db0f3_row3_col7, #T_db0f3_row4_col0, #T_db0f3_row4_col1, #T_db0f3_row4_col2, #T_db0f3_row4_col3, #T_db0f3_row4_col4, #T_db0f3_row4_col5, #T_db0f3_row4_col6, #T_db0f3_row4_col7, #T_db0f3_row5_col0, #T_db0f3_row5_col1, #T_db0f3_row5_col2, #T_db0f3_row5_col3, #T_db0f3_row5_col4, #T_db0f3_row5_col5, #T_db0f3_row5_col6, #T_db0f3_row5_col7, #T_db0f3_row6_col0, #T_db0f3_row6_col1, #T_db0f3_row6_col2, #T_db0f3_row6_col3, #T_db0f3_row6_col4, #T_db0f3_row6_col5, #T_db0f3_row6_col6, #T_db0f3_row6_col7, #T_db0f3_row7_col0, #T_db0f3_row7_col1, #T_db0f3_row7_col2, #T_db0f3_row7_col3, #T_db0f3_row7_col4, #T_db0f3_row7_col5, #T_db0f3_row7_col6, #T_db0f3_row7_col7, #T_db0f3_row8_col0, #T_db0f3_row8_col1, #T_db0f3_row8_col2, #T_db0f3_row8_col3, #T_db0f3_row8_col4, #T_db0f3_row8_col5, #T_db0f3_row8_col6, #T_db0f3_row8_col7, #T_db0f3_row9_col0, #T_db0f3_row9_col1, #T_db0f3_row9_col2, #T_db0f3_row9_col3, #T_db0f3_row9_col4, #T_db0f3_row9_col5, #T_db0f3_row9_col6, #T_db0f3_row9_col7, #T_db0f3_row10_col0, #T_db0f3_row10_col1, #T_db0f3_row10_col2, #T_db0f3_row10_col3, #T_db0f3_row10_col4, #T_db0f3_row10_col5, #T_db0f3_row10_col6, #T_db0f3_row10_col7, #T_db0f3_row11_col0, #T_db0f3_row11_col1, #T_db0f3_row11_col2, #T_db0f3_row11_col3, #T_db0f3_row11_col4, #T_db0f3_row11_col5, #T_db0f3_row11_col6, #T_db0f3_row11_col7, #T_db0f3_row12_col0, #T_db0f3_row12_col1, #T_db0f3_row12_col2, #T_db0f3_row12_col3, #T_db0f3_row12_col4, #T_db0f3_row12_col5, #T_db0f3_row12_col6, #T_db0f3_row12_col7, #T_db0f3_row13_col0, #T_db0f3_row13_col1, #T_db0f3_row13_col2, #T_db0f3_row13_col3, #T_db0f3_row13_col4, #T_db0f3_row13_col5, #T_db0f3_row13_col6, #T_db0f3_row13_col7 {
#   text-align: left;
# }
# #T_db0f3_row0_col1, #T_db0f3_row0_col3, #T_db0f3_row0_col4, #T_db0f3_row0_col5, #T_db0f3_row0_col6, #T_db0f3_row0_col7, #T_db0f3_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_db0f3_row0_col8, #T_db0f3_row1_col8, #T_db0f3_row2_col8, #T_db0f3_row3_col8, #T_db0f3_row4_col8, #T_db0f3_row5_col8, #T_db0f3_row6_col8, #T_db0f3_row7_col8, #T_db0f3_row8_col8, #T_db0f3_row9_col8, #T_db0f3_row10_col8, #T_db0f3_row12_col8, #T_db0f3_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_db0f3_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_db0f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db0f3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_db0f3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_db0f3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_db0f3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_db0f3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_db0f3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_db0f3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_db0f3_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_db0f3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db0f3_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_db0f3_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_db0f3_row0_col1" class="data row0 col1" >0.9857</td>
#       <td id="T_db0f3_row0_col2" class="data row0 col2" >0.9990</td>
#       <td id="T_db0f3_row0_col3" class="data row0 col3" >0.9857</td>
#       <td id="T_db0f3_row0_col4" class="data row0 col4" >0.9860</td>
#       <td id="T_db0f3_row0_col5" class="data row0 col5" >0.9857</td>
#       <td id="T_db0f3_row0_col6" class="data row0 col6" >0.9771</td>
#       <td id="T_db0f3_row0_col7" class="data row0 col7" >0.9773</td>
#       <td id="T_db0f3_row0_col8" class="data row0 col8" >2.0580</td>
#     </tr>
#     <tr>
#       <th id="T_db0f3_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_db0f3_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_db0f3_row1_col1" class="data row1 col1" >0.9848</td>
#       <td id="T_db0f3_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_db0f3_row1_col3" class="data row1 col3" >0.9848</td>
#       <td id="T_db0f3_row1_col4" class="data row1 col4" >0.9850</td>
#       <td id="T_db0f3_row1_col5" class="data row1 col5" >0.9848</td>
#       <td id="T_db0f3_row1_col6" class="data row1 col6" >0.9757</td>
#       <td id="T_db0f3_row1_col7" class="data row1 col7" >0.9758</td>
#       <td id="T_db0f3_row1_col8" class="data row1 col8" >0.3800</td>
#     </tr>
#     <tr>
#       <th id="T_db0f3_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_db0f3_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_db0f3_row2_col1" class="data row2 col1" >0.9838</td>
#       <td id="T_db0f3_row2_col2" class="data row2 col2" >0.9995</td>
#       <td id="T_db0f3_row2_col3" class="data row2 col3" >0.9838</td>
#       <td id="T_db0f3_row2_col4" class="data row2 col4" >0.9841</td>
#       <td id="T_db0f3_row2_col5" class="data row2 col5" >0.9838</td>
#       <td id="T_db0f3_row2_col6" class="data row2 col6" >0.9740</td>
#       <td id="T_db0f3_row2_col7" class="data row2 col7" >0.9742</td>
#       <td id="T_db0f3_row2_col8" class="data row2 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_db0f3_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_db0f3_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_db0f3_row3_col1" class="data row3 col1" >0.9790</td>
#       <td id="T_db0f3_row3_col2" class="data row3 col2" >0.9987</td>
#       <td id="T_db0f3_row3_col3" class="data row3 col3" >0.9790</td>
#       <td id="T_db0f3_row3_col4" class="data row3 col4" >0.9793</td>
#       <td id="T_db0f3_row3_col5" class="data row3 col5" >0.9789</td>
#       <td id="T_db0f3_row3_col6" class="data row3 col6" >0.9663</td>
#       <td id="T_db0f3_row3_col7" class="data row3 col7" >0.9666</td>
#       <td id="T_db0f3_row3_col8" class="data row3 col8" >0.2820</td>
#     </tr>
#     <tr>
#       <th id="T_db0f3_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_db0f3_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_db0f3_row4_col1" class="data row4 col1" >0.9648</td>
#       <td id="T_db0f3_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_db0f3_row4_col3" class="data row4 col3" >0.9648</td>
#       <td id="T_db0f3_row4_col4" class="data row4 col4" >0.9658</td>
#       <td id="T_db0f3_row4_col5" class="data row4 col5" >0.9644</td>
#       <td id="T_db0f3_row4_col6" class="data row4 col6" >0.9431</td>
#       <td id="T_db0f3_row4_col7" class="data row4 col7" >0.9442</td>
#       <td id="T_db0f3_row4_col8" class="data row4 col8" >0.2560</td>
#     </tr>
#     <tr>
#       <th id="T_db0f3_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_db0f3_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_db0f3_row5_col1" class="data row5 col1" >0.9638</td>
#       <td id="T_db0f3_row5_col2" class="data row5 col2" >0.9704</td>
#       <td id="T_db0f3_row5_col3" class="data row5 col3" >0.9638</td>
#       <td id="T_db0f3_row5_col4" class="data row5 col4" >0.9644</td>
#       <td id="T_db0f3_row5_col5" class="data row5 col5" >0.9639</td>
#       <td id="T_db0f3_row5_col6" class="data row5 col6" >0.9422</td>
#       <td id="T_db0f3_row5_col7" class="data row5 col7" >0.
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9857  0.9990  0.9857  0.9860
# gbc          Gradient Boosting Classifier    0.9848  0.0000  0.9848  0.9850
# et                 Extra Trees Classifier    0.9838  0.9995  0.9838  0.9841
# rf               Random Forest Classifier    0.9790  0.9987  0.9790  0.9793
# qda       Quadratic Discriminant Analysis    0.9648  0.0000  0.9648  0.9658
# dt               Decision Tree Classifier    0.9638  0.9704  0.9638  0.9644
# knn                K Neighbors Classifier    0.9543  0.9921  0.9543  0.9574
# nb                            Naive Bayes    0.9543  0.9982  0.9543  0.9580
# lr                    Logistic Regression    0.9476  0.0000  0.9476  0.9489
# svm                   SVM - Linear Kernel    0.9429  0.0000  0.9429  0.9444
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.9857  0.9771  0.9773     2.058
# gbc       0.9848  0.9757  0.9758     0.380
# et        0.9838  0.9740  0.9742     0.034
# rf        0.9789  0.9663  0.9666     0.282
# qda       0.9644  0.9431  0.9442     0.256
# dt        0.9639  0.9422  0.9425     0.264
# knn       0.9546  0.9274  0.9289     0.264
# nb        0.9534  0.9257  0.9289     0.264
# lr        0.9476  0.9161  0.9169     0.594
# svm       0.9426  0.9083  0.9095     0.260
# <style type="text/css">
# #T_f8145_row5_col0, #T_f8145_row5_col1, #T_f8145_row5_col2, #T_f8145_row5_col3, #T_f8145_row5_col4, #T_f8145_row5_col5, #T_f8145_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f8145">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8145_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f8145_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f8145_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f8145_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f8145_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f8145_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f8145_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8145_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8145_row0_col0" class="data row0 col0" >0.9952</td>
#       <td id="T_f8145_row0_col1" class="data row0 col1" >0.9998</td>
#       <td id="T_f8145_row0_col2" class="data row0 col2" >0.9952</td>
#       <td id="T_f8145_row0_col3" class="data row0 col3" >0.9953</td>
#       <td id="T_f8145_row0_col4" class="data row0 col4" >0.9952</td>
#       <td id="T_f8145_row0_col5" class="data row0 col5" >0.9923</td>
#       <td id="T_f8145_row0_col6" class="data row0 col6" >0.9924</td>
#     </tr>
#     <tr>
#       <th id="T_f8145_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8145_row1_col0" class="data row1 col0" >0.9857</td>
#       <td id="T_f8145_row1_col1" class="data row1 col1" >0.9990</td>
#       <td id="T_f8145_row1_col2" class="data row1 col2" >0.9857</td>
#       <td id="T_f8145_row1_col3" class="data row1 col3" >0.9858</td>
#       <td id="T_f8145_row1_col4" class="data row1 col4" >0.9857</td>
#       <td id="T_f8145_row1_col5" class="data row1 col5" >0.9772</td>
#       <td id="T_f8145_row1_col6" class="data row1 col6" >0.9772</td>
#     </tr>
#     <tr>
#       <th id="T_f8145_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8145_row2_col0" class="data row2 col0" >0.9810</td>
#       <td id="T_f8145_row2_col1" class="data row2 col1" >0.9975</td>
#       <td id="T_f8145_row2_col2" class="data row2 col2" >0.9810</td>
#       <td id="T_f8145_row2_col3" class="data row2 col3" >0.9810</td>
#       <td id="T_f8145_row2_col4" class="data row2 col4" >0.9810</td>
#       <td id="T_f8145_row2_col5" class="data row2 col5" >0.9695</td>
#       <td id="T_f8145_row2_col6" class="data row2 col6" >0.9695</td>
#     </tr>
#     <tr>
#       <th id="T_f8145_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8145_row3_col0" class="data row3 col0" >0.9810</td>
#       <td id="T_f8145_row3_col1" class="data row3 col1" >0.9983</td>
#       <td id="T_f8145_row3_col2" class="data row3 col2" >0.9810</td>
#       <td id="T_f8145_row3_col3" class="data row3 col3" >0.9813</td>
#       <td id="T_f8145_row3_col4" class="data row3 col4" >0.9810</td>
#       <td id="T_f8145_row3_col5" class="data row3 col5" >0.9696</td>
#       <td id="T_f8145_row3_col6" class="data row3 col6" >0.9697</td>
#     </tr>
#     <tr>
#       <th id="T_f8145_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8145_row4_col0" class="data row4 col0" >0.9857</td>
#       <td id="T_f8145_row4_col1" class="data row4 col1" >0.9996</td>
#       <td id="T_f8145_row4_col2" class="data row4 col2" >0.9857</td>
#       <td id="T_f8145_row4_col3" class="data row4 col3" >0.9857</td>
#       <td id="T_f8145_row4_col4" class="data row4 col4" >0.9857</td>
#       <td id="T_f8145_row4_col5" class="data row4 col5" >0.9771</td>
#       <td id="T_f8145_row4_col6" class="data row4 col6" >0.9771</td>
#     </tr>
#     <tr>
#       <th id="T_f8145_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_f8145_row5_col0" class="data row5 col0" >0.9857</td>
#       <td id="T_f8145_row5_col1" class="data row5 col1" >0.9988</td>
#       <td id="T_f8145_row5_col2" class="data row5 col2" >0.9857</td>
#       <td id="T_f8145_row5_col3" class="data row5 col3" >0.9858</td>
#       <td id="T_f8145_row5_col4" class="data row5 col4" >0.9857</td>
#       <td id="T_f8145_row5_col5" class="data row5 col5" >0.9771</td>
#       <td id="T_f8145_row5_col6" class="data row5 col6" >0.9772</td>
#     </tr>
#     <tr>
#       <th id="T_f8145_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_f8145_row6_col0" class="data row6 col0" >0.0052</td>
#       <td id="T_f8145_row6_col1" class="data row6 col1" >0.0009</td>
#       <td id="T_f8145_row6_col2" class="data row6 col2" >0.0052</td>
#       <td id="T_f8145_row6_col3" class="data row6 col3" >0.0052</td>
#       <td id="T_f8145_row6_col4" class="data row6 col4" >0.0052</td>
#       <td id="T_f8145_row6_col5" class="data row6 col5" >0.0083</td>
#       <td id="T_f8145_row6_col6" class="data row6 col6" >0.0083</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 33
#      30 tuned_model = tune_model(best_model)
#      32 # 6) Avaliar visualmente
# ---> 33 plot_model(tuned_model, plot='residuals')
#      34 plot_model(tuned_model, plot='error')
#      35 plot_model(tuned_model, plot='feature')
#
# File ~/Documents/FIAP/4ºano/GenerativeAIforEngineering/GlobalSolution/GS1/space_object_predict/.venv/lib/python3.9/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File ~/Documents/FIAP/4ºano/GenerativeAIforEngineering/GlobalSolution/GS1/space_object_predict/.venv/lib/python3.9/site-packages/pycaret/classification/functional.py:1725, in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1611 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1612 def plot_model(
#    1613     estimator,
#    (...)
#    1622     display_format: Optional[str] = None,
#    1623 ) -> Optional[str]:
#    1624     """
#    1625     This function analyzes the performance of a trained model on holdout set.
#    1626     It may require re-training the model in certain cases.
#    (...)
#    1722
#    1723     """
# -> 1725     return _CURRENT_EXPERIMENT.plot_model(
#    1726         estimator=estimator,
#    1727         plot=plot,
#    1728         scale=scale,
#    1729         save=save,
#    1730         fold=fold,
#    1731         fit_kwargs=fit_kwargs,
#    1732         plot_kwargs=plot_kwargs,
#    1733         groups=groups,
#    1734         verbose=verbose,
#    1735         display_format=display_format,
#    1736     )
#
# File ~/Documents/FIAP/4ºano/GenerativeAIforEngineering/GlobalSolution/GS1/space_object_predict/.venv/lib/python3.9/site-packages/pycaret/classification/oop.py:2071, in ClassificationExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1957 def plot_model(
#    1958     self,
#    1959     estimator,
#    (...)
#    1968     display_format: Optional[str] = None,
#    1969 ) -> Optional[str]:
#    1970     """
#    1971     This function analyzes the performance of a trained model on holdout set.
#    1972     It may require re-training the model in certain cases.
#    (...)
#    2068
#    2069     """
# -> 2071     return super().plot_model(
#    2072         estimator=estimator,
#    2073         plot=plot,
#    2074         scale=scale,
#    2075         save=save,
#    2076         fold=fold,
#    2077         fit_kwargs=fit_kwargs,
#    2078         plot_kwargs=plot_kwargs,
#    2079         groups=groups,
#    2080         verbose=verbose,
#    2081         display_format=display_format,
#    2082     )
#
# File ~/Documents/FIAP/4ºano/GenerativeAIforEngineering/GlobalSolution/GS1/space_object_predict/.venv/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:2045, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, verbose, display_format)
#    1933 def plot_model(
#    1934     self,
#    1935     estimator,
#    (...)
#    1946     display_format: Optional[str] = None,
#    1947 ) -> Optional[str]:
#    1948     """
#    1949     This function takes a trained model object and returns a plot based on the
#    1950     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2043
#    2044     """
# -> 2045     return self._plot_model(
#    2046         estimator=estimator,
#    2047         plot=plot,
#    2048         scale=scale,
#    2049         save=save,
#    2050         fold=fold,
#    2051         fit_kwargs=fit_kwargs,
#    2052         plot_kwargs=plot_kwargs,
#    2053         groups=groups,
#    2054         feature_name=feature_name,
#    2055         label=label,
#    2056         verbose=verbose,
#    2057         display_format=display_format,
#    2058     )
#
# File ~/Documents/FIAP/4ºano/GenerativeAIforEngineering/GlobalSolution/GS1/space_object_predict/.venv/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:411, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, verbose, system, display, display_format)
#     406     raise ValueError(
#     407         f"Estimator {estimator} does not have the required fit() method."
#     408     )
#     410 if plot not in self._available_plots:
# --> 411     raise ValueError(
#     412         "Plot Not Available. Please see docstring for list of available Plots."
#     413     )
#     415 # checking display_format parameter
#     416 self.plot_model_check_display_format_(display_format=display_format)
#
# ValueError: Plot Not Available. Please see docstring for list of available Plots.
